# %%
! pip install psycopg2-binary
! pip install flask-sqlalchemy
! pip install Flask-Migrate
! pip install Flask-RESTful
# Out:
# Collecting Flask-RESTful
#   Downloading Flask_RESTful-0.3.9-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pytz in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask-RESTful) (2020.1)
# Requirement already satisfied: Flask>=0.8 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask-RESTful) (2.2.2)
# Requirement already satisfied: six>=1.3.0 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask-RESTful) (1.15.0)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied: click>=8.0 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask>=0.8->Flask-RESTful) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask>=0.8->Flask-RESTful) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask>=0.8->Flask-RESTful) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0; python_version < "3.10" in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask>=0.8->Flask-RESTful) (4.11.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Flask>=0.8->Flask-RESTful) (3.0.3)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from click>=8.0->Flask>=0.8->Flask-RESTful) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from Werkzeug>=2.2.2->Flask>=0.8->Flask-RESTful) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=0.8->Flask-RESTful) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jonow\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata>=3.6.0; python_version < "3.10"->Flask>=0.8->Flask-RESTful) (3.7.0)
# Installing collected packages: aniso8601, Flask-RESTful
# Successfully installed Flask-RESTful-0.3.9 aniso8601-9.0.1
