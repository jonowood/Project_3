# %% [markdown]
# Import Depencies

# %%
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
import numpy as np
# import gmaps

# # Import API key
# from api_keys import geoapify_key
# from api_keys import gmaps_key

# gmaps.configure(api_key={gmaps_key})

# %% [markdown]
# Set header to circumvent webscraping blocker

# %%
headers = {
    "User-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"}

# %% [markdown]
# Create lists to store **responses**

# %%
# data to scrape
job_title = []
company_name = []
short_description = []
job_location = []
job_classification = []
job_subclassification = []
job_site = []

job_counter = 0

# %%
headers = {
     "User-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"
}

# %% [markdown]
# Scrape the website

# %%
# url = 'https://www.seek.com.au/jobs-in-construction/in-All-Perth-WA'
# response = requests.get(url)
# soup = BeautifulSoup(response.content, features='html.parser')
# jobs_on_page = soup('article')

# %% [markdown]
# Create list of scraping variables (job fields, pages[4])

# %%
job_field = ['construction', 'engineering', 'healthcare-medical', 'sales', 'jobs-in-community-services-development']
page_scrapes = ['', '?page=2', '?page=3','?page=4','?page=5']

# %% [markdown]
# Scrape data

# %%
for x in job_field:

    for page in page_scrapes:

        url = 'https://www.seek.com.au/jobs-in-' + x + '/in-All-Perth-WA' + page
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, features='html.parser')
        jobs_on_page = soup('article')
            
        for i in range(len(jobs_on_page)):

            job_counter += 1 
            
            job_title.append(soup('article')[i]['aria-label'])
            job_site.append("Seek.com.au")
            short_description.append(soup('article')[i].find('span', {'data-automation':'jobShortDescription'}).text)
            job_location.append(soup('article')[i].find('a', {'data-automation':'jobLocation'}).text)
            job_subclassification.append(soup('article')[i].find('a', {'data-automation':'jobSubClassification'}).text)
            job_classification.append(soup('article')[i].find('a', {'data-automation':'jobClassification'}).text)
            
            print('Jobs scraped: %d' % job_counter, end='\r')
            
            try:
                company_name.append(soup('article')[i].find('a', {'data-automation':'jobCompany'}).text)
            except:
                company_name.append(np.nan)
# Out:
# Jobs scraped: 487

# %% [markdown]
# -------

# %% [markdown]
# # end of scrape

# %%
print(len(company_name))
print(len(job_title))
print(len(short_description))
# Out:
# 487
# 487
# 487

# %%
seek_data = {'job_title': job_title,
            'company_name': company_name,
            'short_description': short_description,
            'job_location': job_location,
            'job_classification': job_classification,
            'job_subclassification': job_subclassification,
            'job_site' : job_site
             }

# %%
seek_data_df = pd.DataFrame(seek_data)
seek_data_df.reset_index(inplace=True)
seek_data_df.rename(columns= {'index':'job_id'}, inplace=True)
seek_data_df.tail(150)
# Out:
#      job_id                                       job_title  \
# 337     337                               Territory Manager
# 338     338                                   State Manager
# 339     339                    B2B Key Account Manager - WA
# 340     340                    Business Development Manager
# 341     341                               Territory Manager
# ..      ...                                             ...
# 482     482                ParentsNext - Engagement Officer
# 483     483        Resident Wellbeing Assistant (Aged Care)
# 484     484         Traineeship - Individual Support Person
# 485     485  Council Services Manager (Operational Manager)
# 486     486            Claims Officer - Employment Services
#
#                       company_name  \
# 337                     DuluxGroup
# 338                            NaN
# 339                      Nespresso
# 340                     District32
# 341             Michael Page Sales
# ..                             ...
# 482        Training Alliance Group
# 483  Singleton Community Aged Care
# 484   Programmed Skilled Workforce
# 485   West Arnhem Regional Council
# 486        Training Alliance Group
#
#                                      short_description  job_location  \
# 337  An exciting opportunity for an energetic and p...    Rockingham
# 338  Are you an outcome focussed Manager with a pas...  Canning Vale
# 339  We currently have an exciting opportunity for ...      Perth WA
# 340  Dynamic business development role for a busine...      Perth WA
# 341  Visiting customers across WA, including going ...      Perth WA
# ..                                                 ...           ...
# 482  Support parents with young children in identif...  Osborne Park
# 483  Signature Care presents an exciting opportunit...     Singleton
# 484  Traineeship- CHC33015 Cert III in Individual S...      Perth WA
# 485  Live and work in the amazing West Arnhem Land,...      Perth WA
# 486  Review and process Employment Services claims ...    West Perth
#
#                    job_classification              job_subclassification  \
# 337                             Sales  Account & Relationship Management
# 338                             Sales                         Management
# 339                             Sales  Account & Relationship Management
# 340                             Sales           New Business Development
# 341                             Sales           New Business Development
# ..                                ...                                ...
# 482  Community Services & Development                Employment Services
# 483  Community Services & Development          Aged & Disability Support
# 484  Community Services & Development          Aged & Disability Support
# 485  Community Services & Development                         Management
# 486  Community Services & Development                Employment Services
#
#         job_site
# 337  Seek.com.au
# 338  Seek.com.au
# 339  Seek.com.au
# 340  Seek.com.au
# 341  Seek.com.au
# ..           ...
# 482  Seek.com.au
# 483  Seek.com.au
# 484  Seek.com.au
# 485  Seek.com.au
# 486  Seek.com.au
#
# [150 rows x 8 columns]

# %% [markdown]
# ---
#
# ## Create dataframes for tables
#
# ---

# %%
# Create job_id dataframe

job_id_df = seek_data_df[['job_id', 'job_classification', 'job_location']].copy()

# rename columns to match schema
job_id_df.rename(columns= {'job_classification':'job_field'}, inplace=True)


job_id_df
# Out:
#      job_id                         job_field  job_location
# 0         0                      Construction        Malaga
# 1         1                      Construction      Perth WA
# 2         2                      Construction  Osborne Park
# 3         3                      Construction      Balcatta
# 4         4                      Construction  Osborne Park
# ..      ...                               ...           ...
# 482     482  Community Services & Development  Osborne Park
# 483     483  Community Services & Development     Singleton
# 484     484  Community Services & Development      Perth WA
# 485     485  Community Services & Development      Perth WA
# 486     486  Community Services & Development    West Perth
#
# [487 rows x 3 columns]

# %% [markdown]
# ### Count words to plot - All Employment Fields

# %%
# Word Cloud Data

full_count = (seek_data_df['short_description'].str.split(expand=True)
              .stack())
full_count_df = pd.DataFrame(full_count)
full_count_df = full_count_df[full_count_df[0].str.len() > 4]
full_count_df
# Out:
#                    0
# 0   1       exciting
#     2    opportunity
#     5        project
#     6       delivery
#     10  enthusiastic
# ...              ...
# 486 4       Services
#     5         claims
#     8    Centralised
#     9         Claims
#     10         team!
#
# [4548 rows x 1 columns]

# %%
# count, tally and describe words in short_description

seek_count = (seek_data_df['short_description'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('word')
              .reset_index(name='count'))

# %%
seek_count = seek_count[seek_count['word'].str.len() > 4]
seek_count
# Out:
#              word  count
# 12    opportunity     89
# 18        Manager     49
# 20        looking     44
# 24        seeking     38
# 26       exciting     36
# ...           ...    ...
# 2352        FIFO.      1
# 2353    February.      1
# 2354        'Make      1
# 2357       start.      1
# 2358      ideally      1
#
# [1923 rows x 2 columns]

# %%
seek_count.head(45)
# Out:
#             word  count
# 12   opportunity     89
# 18       Manager     49
# 20       looking     44
# 24       seeking     38
# 26      exciting     36
# 27   experienced     35
# 28       Project     35
# 31         Perth     31
# 32      Engineer     30
# 33         sales     29
# 34         based     27
# 36         their     26
# 37        people     26
# 41       Medical     23
# 42         great     23
# 43       project     23
# 44      business     22
# 47        career     21
# 49        within     21
# 51      projects     20
# 53    experience     20
# 54       support     19
# 55         Sales     19
# 58       company     18
# 60       Support     18
# 62  construction     17
# 65        across     16
# 66         team.     16
# 70      Exciting     15
# 72    Mechanical     15
# 73         Great     15
# 75   engineering     15
# 76    Supervisor     14
# 77     currently     14
# 79       dynamic     14
# 80    management     13
# 81      building     13
# 82       working     13
# 83       develop     13
# 85   Engineering     13
# 86    individual     13
# 87   Opportunity     13
# 89      industry     13
# 90       Western     12
# 92  Construction     12

# %% [markdown]
# ### Count words to plot - Individual fields (Construction, Engineering, Healthcare, Sales, Community Services)

# %%
# Create DF for each job field

construction_df = seek_data_df[seek_data_df['job_classification']=='Construction']
engineering_df = seek_data_df[seek_data_df['job_classification']=='Engineering']
healthcare_medical_df = seek_data_df[seek_data_df['job_classification']=='Healthcare & Medical']
sales_df = seek_data_df[seek_data_df['job_classification']=='Sales']
jobs_in_community_services_development_df = seek_data_df[seek_data_df['job_classification']=='Community Services & Development']

# %%
# create word count DF for each job field
# word cloud
# count, tally and describe words in short_description


# construction

construction_count = (construction_df['short_description'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('word')
              .reset_index(name='count'))

# engineering

engineering_count = (engineering_df['short_description'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('word')
              .reset_index(name='count'))

# healthcare

healthcare_medical_count = (healthcare_medical_df['short_description'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('word')
              .reset_index(name='count'))

# sales

sales_count = (sales_df['short_description'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('word')
              .reset_index(name='count'))

# community service
jobs_in_community_services_development_count = (jobs_in_community_services_development_df['short_description'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('word')
              .reset_index(name='count'))

# %%
# word cloud


# construction

construction_set = construction_df.stack().str.split("[^\w+]").explode().tolist()
construction_count_df = pd.DataFrame(construction_set)
construction_count_df = construction_count_df[construction_count_df[0].str.len() > 4]


# engineering

engineering_set = engineering_df.stack().str.split("[^\w+]").explode().tolist()
engineering_count_df = pd.DataFrame(engineering_set)
engineering_count_df = engineering_count_df[engineering_count_df[0].str.len() > 4]

# healthcare

healthcare_set = healthcare_medical_df.stack().str.split("[^\w+]").explode().tolist()
healthcare_count_df = pd.DataFrame(healthcare_set)
healthcare_count_df = healthcare_count_df[healthcare_count_df[0].str.len() > 4]

# sales

sales_set = sales_df.stack().str.split("[^\w+]").explode().tolist()
sales_count_df = pd.DataFrame(healthcare_set)
sales_count_df = sales_count_df[sales_count_df[0].str.len() > 4]

# community service
community_set = sales_df.stack().str.split("[^\w+]").explode().tolist()
community_count_df = pd.DataFrame(community_set)
community_count_df = community_count_df[community_count_df[0].str.len() > 4]

construction_count_df.rename(columns= {0:'word'}, inplace=True)
engineering_count_df.rename(columns= {0:'word'}, inplace=True)
healthcare_count_df.rename(columns= {0:'word'}, inplace=True)
sales_count_df.rename(columns= {0:'word'}, inplace=True)
community_count_df.rename(columns= {0:'word'}, inplace=True)
construction_count_df.reset_index(drop=True)



construction_count_df.head(40)
# Out:
#             word
# 1        Project
# 2    Coordinator
# 5       Graduate
# 6       Aluglaze
# 8       exciting
# 9    opportunity
# 12       project
# 13      delivery
# 17  enthusiastic
# 19      aspiring
# 20       project
# 21    management
# 22  professional
# 24        Malaga
# 25  Construction
# 26       Project
# 27    Management
# 33    PROTECTION
# 34       MANAGER
# 35       Quenmor
# 37    Protection
# 38       Manager
# 40       Quenmor
# 42    Protection
# 44      Exciting
# 45   opportunity
# 46        awaits
# 48         right
# 49     candidate
# 51         Perth
# 53  Construction
# 54    Management
# 59       Trainee
# 61    Supervisor
# 64        Luxury
# 65        Timber
# 66      Flooring
# 67      Retailer
# 68       Exelect
# 69   Recruitment

# %%
# remove words with less than 5 characters

construction_count = construction_count[construction_count['word'].str.len() > 4]
engineering_count = engineering_count[engineering_count['word'].str.len() > 4]
healthcare_medical_count = healthcare_medical_count[healthcare_medical_count['word'].str.len() > 4]
sales_count = sales_count[sales_count['word'].str.len() > 4]
jobs_in_community_services_development_words = jobs_in_community_services_development_count[jobs_in_community_services_development_count['word'].str.len() > 4]

# %%
jobs_in_community_services_development_words
# Out:
#             word  count
# 4          their     16
# 7        Support     14
# 9         people     13
# 15   opportunity      7
# 18       helping      6
# ..           ...    ...
# 394  Coordinator      1
# 395        Fixed      1
# 396        guide      1
# 397      Belmont      1
# 398     valuable      1
#
# [285 rows x 2 columns]

# %% [markdown]
# ### Count locations to plot
#
# -----

# %%
# seek_data_df
# jobs_in_community_services_development_df

# %%
# create df for location counts 
# heatmap plot

all_fields_locations = seek_data_df['job_location'].value_counts()
construction_locations = construction_df['job_location'].value_counts()
engineering_locations = engineering_df['job_location'].value_counts()
healthcare_medical_locations = healthcare_medical_df['job_location'].value_counts()
sales_locations = sales_df['job_location'].value_counts()
jobs_in_community_services_development_locations = jobs_in_community_services_development_df['job_location'].value_counts()

all_fields_locations_df = pd.DataFrame(all_fields_locations)
construction_locations_df = pd.DataFrame(construction_locations)
engineering_locations_df = pd.DataFrame(engineering_locations)
healthcare_medical_locations_df = pd.DataFrame(healthcare_medical_locations)
sales_locations_df = pd.DataFrame(sales_locations)
jobs_in_community_services_development_locations = pd.DataFrame(jobs_in_community_services_development_locations)

jobs_in_community_services_development_locations
# Out:
#                 job_location
# Perth WA                  15
# Bayswater                  2
# Cloverdale                 2
# Rockingham                 2
# Osborne Park               2
# Midland                    2
# Rivervale                  2
# Belmont                    1
# Tuart Hill                 1
# West Perth                 1
# Mirrabooka                 1
# Warnbro                    1
# Kwinana Beach              1
# Fremantle                  1
# Mosman Park                1
# Maylands                   1
# Bentley                    1
# Balga                      1
# Butler                     1
# Claremont                  1
# Malaga                     1
# Forrestfield               1
# Singleton                  1
# Mount Pleasant             1
# Thornlie                   1
# Wembley                    1
# Wanneroo                   1

# %%
# reset index for tables
all_fields_locations_df.reset_index(inplace=True)
sales_locations_df.reset_index(inplace=True)
construction_locations_df.reset_index(inplace=True)
healthcare_medical_locations_df.reset_index(inplace=True)
engineering_locations_df.reset_index(inplace=True)
jobs_in_community_services_development_locations.reset_index(inplace=True)

# %%
# rename columns to be more friendly
all_fields_locations_df.rename(columns= {'index':'job_location', 'job_location':'count'}, inplace=True)
engineering_locations_df.rename(columns= {'index':'job_location', 'job_location':'count'}, inplace=True)
construction_locations_df.rename(columns= {'index':'job_location', 'job_location':'count'}, inplace=True)
healthcare_medical_locations_df.rename(columns= {'index':'job_location', 'job_location':'count'}, inplace=True)
sales_locations_df.rename(columns= {'index':'job_location', 'job_location':'count'}, inplace=True)
jobs_in_community_services_development_locations.rename(columns= {'index':'job_location', 'job_location':'count'}, inplace=True)
engineering_locations_df
# Out:
#             job_location  count
# 0               Perth WA     54
# 1                 Malaga      6
# 2              Henderson      5
# 3           Canning Vale      4
# 4                Wangara      3
# 5              Welshpool      3
# 6              Hazelmere      2
# 7                Bentley      2
# 8            Forrestdale      2
# 9               Kardinya      2
# 10              Jandakot      2
# 11               Subiaco      2
# 12                Myaree      2
# 13             Bayswater      2
# 14               Wembley      2
# 15            Bibra Lake      2
# 16           Leederville      1
# 17               Belmont      1
# 18                 Ascot      1
# 19            West Perth      1
# 20               Midland      1
# 21         Kwinana Beach      1
# 22              Balcatta      1
# 23              Wanneroo      1
# 24         Perth Airport      1
# 25          North Coogee      1
# 26             Rivervale      1
# 27             Cottesloe      1
# 28         Garden Island      1
# 29  Rockingham & Kwinana      1
# 30                Butler      1

# %%
###### DEBUG - REMOVE

# seek_csv_data = seek_count.to_csv('seek_count.csv', index = True)
# print('\nCSV String:\n', seek_csv_data)

# %% [markdown]
# ------

# %% [markdown]
# ### Connect to postgres and load data to db
#
# -----

# %%
# MOVE TO TOP BEFORE SUBMITTING

from api_keys import postgres_p
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
protocol = 'postgresql'
username = 'postgres'
password = postgres_p

host = 'localhost'

port = 5432

database_name = 'Project_3'

rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
insp = inspect(engine)

insp.get_table_names()
# Out:
# ['job_id',
#  'construction_scrapes',
#  'engineering_scrapes',
#  'healthcare_scrapes',
#  'sales_scrapes',
#  'community_service_scrapes',
#  'allfields_location_count',
#  'construction_location_count',
#  'engineering_location_count',
#  'healthcare_location_count',
#  'sales_location_count',
#  'community_services_location_count',
#  'sales_word_count',
#  'community_services_word_count',
#  'healthcare_word_count',
#  'construction_word_count',
#  'engineering_word_count',
#  'all_fields_word_count',
#  'sales_words',
#  'community_services_words',
#  'healthcare_words',
#  'construction_words',
#  'engineering_words',
#  'all_fields_words',
#  'community_service_count']

# %%
jobs_in_community_services_development_df
# Out:
#      job_id                                          job_title  \
# 440     440                               APS4 Access Assessor
# 441     441                                   NDIA APS5 Lawyer
# 442     442                 APS5 National Reassessment Officer
# 443     443  APS5 Remote Support & Coordination - Affirmati...
# 444     444  Home Care Employee - Multiple positions - High...
# 445     445                               Job Coach - Wanneroo
# 446     446         Employability Skills Trainer (Perth South)
# 447     447         Employability Skills Trainer (Perth North)
# 448     448                        Recruiters Seeking A Change
# 449     449                          Community Support Workers
# 450     450                        Employer Engagement Partner
# 451     451                Philanthropy & Partnerships Manager
# 452     452                         Safety and Support Officer
# 453     453  Duty Social Worker - Foster Care-  PT - Fterm ...
# 454     454   Family Support Worker - Foster Care - Cloverdale
# 455     455                                     CLIENT ADVISOR
# 456     456                     Employment Services Consultant
# 457     457                             Support Worker/ Mentor
# 458     458                                Job Coach - Warnbro
# 459     459                      Employment Support Consultant
# 460     460                   Disability Mentor/Support Worker
# 461     461                    Aboriginal Services Coordinator
# 462     462                           Community Support Worker
# 463     463         Innovative Employment Advisor - Disability
# 464     464                                     Support Worker
# 465     465                 Security Officer / Ranger (Casual)
# 466     466                           High care Support Worker
# 467     467          Support Worker - Forrestfield & Kalamunda
# 468     468                     Recovery Partner - Night Shift
# 469     469                            Support Worker - Butler
# 470     470                        Support Worker - Tuart Hill
# 471     471                                    Support Workers
# 472     472                     Home Care Clinical Coordinator
# 473     473                         Respite Centre Coordinator
# 474     474            Disability Support Worker - Mosman Park
# 475     475                 Playgroup Support Worker - Boronia
# 476     476  Assurance and Compliance Officer WA - Pacific ...
# 477     477                        Support Worker - Perth City
# 478     478                            Senior Recovery Partner
# 479     479            Support worker - Rockingham & Surrounds
# 480     480    High care Support Worker  - Claremont & Floreat
# 481     481                                     Support Worker
# 482     482                   ParentsNext - Engagement Officer
# 483     483           Resident Wellbeing Assistant (Aged Care)
# 484     484            Traineeship - Individual Support Person
# 485     485     Council Services Manager (Operational Manager)
# 486     486               Claims Officer - Employment Services
#
#                                           company_name  \
# 440               National Disability Insurance Scheme
# 441               National Disability Insurance Scheme
# 442               National Disability Insurance Scheme
# 443               National Disability Insurance Scheme
# 444                                     At Home Health
# 445                                   atWork Australia
# 446                            Training Alliance Group
# 447                            Training Alliance Group
# 448                                              CCIWA
# 449                                              Vitil
# 450                                               genU
# 451                                           RSPCA WA
# 452                                         Uniting WA
# 453                                        Wanslea Ltd
# 454                                        Wanslea Ltd
# 455                            ECHO Community Services
# 456                                WorkFocus Australia
# 457                                                NaN
# 458                                   atWork Australia
# 459                  Maxima Training Group (Aust) Ltd.
# 460                                     Mighty Mentors
# 461                               Henderson Healthcare
# 462                     Autism Association of WA (Inc)
# 463                            Valued Lives Foundation
# 464                       Aberstone Community Services
# 465                                  City of Bayswater
# 466                                              Avivo
# 467                                              Avivo
# 468                      Southern Cross Care (WA) Inc.
# 469                                              Avivo
# 470                                              Avivo
# 471                       Aberstone Community Services
# 472                      Southern Cross Care (WA) Inc.
# 473                      Southern Cross Care (WA) Inc.
# 474                                              Avivo
# 475                                            YMCA WA
# 476  Palladium International Pty Ltd -Pacific Labou...
# 477                                              Avivo
# 478                      Southern Cross Care (WA) Inc.
# 479                                              Avivo
# 480                                              Avivo
# 481                      Southern Cross Care (WA) Inc.
# 482                            Training Alliance Group
construction_df.to_sql(name='construction_scrapes', con=engine, if_exists='append', index=False)
engineering_df.to_sql(name='engineering_scrapes', con=engine, if_exists='append', index=False)
healthcare_medical_df.to_sql(name='healthcare_scrapes', con=engine, if_exists='append', index=False)
sales_df.to_sql(name='sales_scrapes', con=engine, if_exists='append', index=False)
jobs_in_community_services_development_df.to_sql(name='community_service_scrapes', con=engine, if_exists='append', index=False)

# ## Word Tables

construction_count_df.to_sql(name='construction_words', con=engine, if_exists='append', index=False)
engineering_count_df.to_sql(name='engineering_words', con=engine, if_exists='append', index=False)
healthcare_count_df.to_sql(name='healthcare_words', con=engine, if_exists='append', index=False)
sales_count_df.to_sql(name='sales_words', con=engine, if_exists='append', index=False)
community_count_df.to_sql(name='community_services_words', con=engine, if_exists='append', index=False)

# ## Word counts

construction_count.to_sql(name='construction_word_count', con=engine, if_exists='append', index=False)
engineering_count.to_sql(name='engineering_word_count', con=engine, if_exists='append', index=False)
healthcare_medical_count.to_sql(name='healthcare_word_count', con=engine, if_exists='append', index=False)
sales_count.to_sql(name='sales_word_count', con=engine, if_exists='append', index=False)
jobs_in_community_services_development_words.to_sql(name='community_services_word_count', con=engine, if_exists='append', index=False)

# ## Location Tables

all_fields_locations_df.to_sql(name='allfields_location_count', con=engine, if_exists='append', index=False)
engineering_locations_df.to_sql(name='engineering_location_count', con=engine, if_exists='append', index=False)
construction_locations_df.to_sql(name='construction_location_count', con=engine, if_exists='append', index=False)
healthcare_medical_locations_df.to_sql(name='healthcare_location_count', con=engine, if_exists='append', index=False)
sales_locations_df.to_sql(name='sales_location_count', con=engine, if_exists='append', index=False)
jobs_in_community_services_development_locations.to_sql(name='community_services_location_count', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from Engineering_Words', con=engine).head(15)
# Out:
#              word
# 0        Graduate
# 1        Engineer
# 2          Teekay
# 3        Shipping
# 4       Australia
# 5         largest
# 6       respected
# 7   international
# 8        shipping
# 9       companies
# 10          world
# 11      Henderson
# 12    Engineering
# 13          Other
# 14        Project

# %%
pd.read_sql_query('select * from construction_word_count', con=engine).head(15)
# Out:
#             word  count
# 0    opportunity     26
# 1        Manager     19
# 2        Project     15
# 3     Supervisor     14
# 4        looking     13
# 5    experienced     13
# 6        project     12
# 7       exciting     12
# 8   Construction     11
# 9        seeking     10
# 10  construction     10
# 11      building      9
# 12         based      9
# 13      projects      8
# 14   Residential      8

# %%
# location_list = []

# %%
# # Create location df for coordinates

# location_list_list = seek_data_df['job_location'].unique().tolist() 

# location_list = pd.DataFrame(seek_data_df['job_location'].unique())

# %%
# location_list.columns = ['job_location']
# location_list

# %%
# for address in location_list:
#     params = {
#          "key" : gmaps_key,
#          "address": address
#     }
#     base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
#     response = requests.get(base_url, params = params).json()
#     response.keys()
#     if response ["status"] == "OK":
#          geometry = response["results"][0]["geometry"]
#          latitude = geometry["location"]["lat"]
#          longitude = geometry["location"]["lng"]
#          location.iloc[[1]] = longitude
#          print(geometry)

# %%
# temp = ''

# location_list['lon'] = temp
# location_list['lat'] = temp

# %%
print(response)

# %%
location_list
