# %%
from bs4 import BeautifulSoup
import requests
import os
import urllib
import pandas as pd
import numpy as np
import requests
import lxml
import time

# %% [markdown]
# ---------------------

# %%
url = 'https://www.seek.com.au/jobs/in-Perth-WA-6000'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="no-referrer-when-downgrade" name="referrer"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="SEEK" name="apple-mobile-web-app-title"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="MC4zODU1Nzg4NDM1MTEzNDk0" name="request-id"/>
#   <meta content="#0d3880" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <link href="/static/shared-web/favicon-4e1897dfd0901e8a3bf7e604d3a90636.ico" rel="icon"/>
#   <link href="/static/shared-web/iphone-7c4d7dcb05fece466d8901945e36bbaa.png" rel="apple-touch-icon"/>
#   <link href="/static/shared-web/ipad-96988dd1c0902fd20b34ce260d03729b.png" rel="apple-touch-icon" sizes="76x76"/>
# ...

# %%
# results = soup.find_all('div', class_='yvsb870 _14uh994p _14uh994u _1r0fdjs0')
results = soup.find_all(id="resultsCol")

# %%
print(results)
# Out:
# []

# %%
getVars = {'q' : 'job_title', 'l' : 'location', 'fromage' : 'last', 'sort' : 'date'}

# %%
url = ('https://www.indeed.com.au/jobs?' + urllib.parse.urlencode(getVars))
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
job_soup = soup.find(id="resultsCol")

# %%
print(job_soup)
# Out:
# None

# %%
# for result in results:
#     # Error handling
#     try:
#         # Identify and return title of listing
#         title = result.find('a', class_='title').text
#         # Identify and return price of listing
#         price = result.find('h4', class_='price').text
#         # Identify and return link to listing
#         link = result.a['href']

#         # Print results only if title, price, and link are available
#         if (title and price and link):
#             print('-------------')
#             print(title)
#             print(price)
#             print(link)
#     except AttributeError as e:
#         print(e)
